# %%
import pandas as pd
import numpy as np
import scipy as sc
import scipy.stats as st
import statsmodels.formula.api as sm
import patsy as pt
import sklearn.linear_model as lm

# %%
df = pd.DataFrame({'years': [2001,
2002,
2003,
2004,
2005,
2006,
2007,
2008,
2009,
2010,
2011,
2012,
2013,
2014,
2015,
2016,
2017,
2018,
2019,
2020,
2021,
2022,
2023,
],
'y': [3.75,
3.95,
2.34,
4.05,
3.82,
4.10,
2.42,
2.89,
4.95,
3.68,
2.15,
3.64,
2.85,
4.92,
4.85,
3.78,
3.61,
3.92,
2.57,
3.22,
4.16,
3.72,
2.20
], 'x1': [20.99,
22.71,
16.18,
21.29,
21.00,
20.14,
18.43,
19.55,
24.71,
21.67,
17.14,
18.22,
18.78,
24.88,
25.05,
21.89,
21.16,
22.00,
17.83,
19.16,
22.50,
19.68,
15.89
], 'x2': [6.26,
7.27,
5.85,
7.07,
6.66,
7.02,
6.27,
5.84,
8.20,
7.31,
4.67,
6.96,
6.21,
7.44,
7.75,
6.13,
6.79,
7.42,
6.60,
5.53,
7.57,
6.18,
5.14
], 'x3': [-0.03,
-0.24,
-0.12,
-0.09,
0.34,
0.11,
-0.46,
-0.39,
-0.21,
0.16,
-0.07,
0.10,
-0.36,
0.09,
-0.34,
-0.10,
-0.19,
0.04,
0.09,
0.24,
-0.45,
0.17,
-0.20
]})

# %%
df
# Out:
#     years     y     x1    x2    x3
# 0    2001  3.75  20.99  6.26 -0.03
# 1    2002  3.95  22.71  7.27 -0.24
# 2    2003  2.34  16.18  5.85 -0.12
# 3    2004  4.05  21.29  7.07 -0.09
# 4    2005  3.82  21.00  6.66  0.34
# 5    2006  4.10  20.14  7.02  0.11
# 6    2007  2.42  18.43  6.27 -0.46
# 7    2008  2.89  19.55  5.84 -0.39
# 8    2009  4.95  24.71  8.20 -0.21
# 9    2010  3.68  21.67  7.31  0.16
# 10   2011  2.15  17.14  4.67 -0.07
# 11   2012  3.64  18.22  6.96  0.10
# 12   2013  2.85  18.78  6.21 -0.36
# 13   2014  4.92  24.88  7.44  0.09
# 14   2015  4.85  25.05  7.75 -0.34
# 15   2016  3.78  21.89  6.13 -0.10
# 16   2017  3.61  21.16  6.79 -0.19
# 17   2018  3.92  22.00  7.42  0.04
# 18   2019  2.57  17.83  6.60  0.09
# 19   2020  3.22  19.16  5.53  0.24
# 20   2021  4.16  22.50  7.57 -0.45
# 21   2022  3.72  19.68  6.18  0.17
# 22   2023  2.20  15.89  5.14 -0.20

# %%
#df = pd.DataFrame('x1', columns = df.x1)
df = d.drop(["years"], axis = 1)

# %%
grr = pd.scatter_matrix(df, c = 'g', figsize=(15, 15), marker = 'o', hist_kwds={'bins': 4}, s=60, alpha=.8)
# Out:
# c:\programdata\miniconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
model1_1 = sm.ols(formula='y ~ x1', data = df)
fitted1_1 = model1_1.fit()
fitted1_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     131.8
# Date:                Sun, 01 Jul 2018   Prob (F-statistic):           1.64e-10
# Time:                        12:44:03   Log-Likelihood:                -5.2658
# No. Observations:                  23   AIC:                             14.53
# Df Residuals:                      21   BIC:                             16.80
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.6088      0.540     -4.830      0.000      -3.732      -1.486
# x1             0.3006      0.026     11.481      0.000       0.246       0.355
# ==============================================================================
# Omnibus:                        4.618   Durbin-Watson:                   2.401
# Prob(Omnibus):                  0.099   Jarque-Bera (JB):                2.841
# Skew:                           0.818   Prob(JB):                        0.242
# Kurtosis:                       3.538   Cond. No.                         168.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model1_2 = sm.ols(formula='y ~ x2', data = df)
fitted1_2 = model1_2.fit()
fitted1_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.694
# Method:                 Least Squares   F-statistic:                     50.85
# Date:                Sun, 01 Jul 2018   Prob (F-statistic):           4.95e-07
# Time:                        12:44:04   Log-Likelihood:                -13.944
# No. Observations:                  23   AIC:                             31.89
# Df Residuals:                      21   BIC:                             34.16
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.8251      0.759     -2.404      0.026      -3.404      -0.246
# x2             0.8119      0.114      7.131      0.000       0.575       1.049
# ==============================================================================
# Omnibus:                        0.769   Durbin-Watson:                   2.181
# Prob(Omnibus):                  0.681   Jarque-Bera (JB):                0.771
# Skew:                          -0.366   Prob(JB):                        0.680
# Kurtosis:                       2.482   Cond. No.                         53.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model1_3 = sm.ols(formula='y ~ x3', data = df)
fitted1_3 = model1_3.fit()
fitted1_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                 -0.031
# Method:                 Least Squares   F-statistic:                    0.3315
# Date:                Sun, 01 Jul 2018   Prob (F-statistic):              0.571
# Time:                        12:44:05   Log-Likelihood:                -27.909
# No. Observations:                  23   AIC:                             59.82
# Df Residuals:                      21   BIC:                             62.09
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.5834      0.190     18.892      0.000       3.189       3.978
# x3             0.4602      0.799      0.576      0.571      -1.202       2.123
# ==============================================================================
# Omnibus:                        0.367   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.832   Jarque-Bera (JB):                0.508
# Skew:                           0.002   Prob(JB):                        0.776
# Kurtosis:                       2.272   Cond. No.                         4.53
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model2_1 = sm.ols(formula='y ~ x1 +x2', data = df)
fitted2_1 = model2_1.fit()
fitted2_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     77.31
# Date:                Sun, 01 Jul 2018   Prob (F-statistic):           3.88e-10
# Time:                        12:44:06   Log-Likelihood:                -3.1702
# No. Observations:                  23   AIC:                             12.34
# Df Residuals:                      20   BIC:                             15.75
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.8707      0.522     -5.500      0.000      -3.960      -1.782
# x1             0.2329      0.042      5.571      0.000       0.146       0.320
# x2             0.2492      0.125      1.999      0.059      -0.011       0.509
# ==============================================================================
# Omnibus:                        0.356   Durbin-Watson:                   2.338
# Prob(Omnibus):                  0.837   Jarque-Bera (JB):                0.399
# Skew:                           0.254   Prob(JB):                        0.819
# Kurtosis:                       2.602   Cond. No.                         183.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model2_2 = sm.ols(formula='y ~ x2 +x3', data = df)
fitted2_2 = model2_2.fit()
fitted2_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     27.80
# Date:                Sun, 01 Jul 2018   Prob (F-statistic):           1.68e-06
# Time:                        12:44:07   Log-Likelihood:                -12.798
# No. Observations:                  23   AIC:                             31.60
# Df Residuals:                      20   BIC:                             35.00
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.8267      0.740     -2.468      0.023      -3.371      -0.283
# x2             0.8198      0.111      7.377      0.000       0.588       1.052
# x3             0.6155      0.425      1.448      0.163      -0.271       1.502
# ==============================================================================
# Omnibus:                        2.187   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.335   Jarque-Bera (JB):                1.438
# Skew:                          -0.612   Prob(JB):                        0.487
# Kurtosis:                       2.941   Cond. No.                         53.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model2_3 = sm.ols(formula='y ~ x1 +x3', data = df)
fitted2_3 = model2_3.fit()
fitted2_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.886
# Method:                 Least Squares   F-statistic:                     86.12
# Date:                Sun, 01 Jul 2018   Prob (F-statistic):           1.48e-10
# Time:                        12:44:09   Log-Likelihood:                -2.0641
# No. Observations:                  23   AIC:                             10.13
# Df Residuals:                      20   BIC:                             13.53
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.6281      0.482     -5.457      0.000      -3.633      -1.623
# x1             0.3043      0.023     13.010      0.000       0.256       0.353
# x3             0.6760      0.267      2.534      0.020       0.119       1.232
# ==============================================================================
# Omnibus:                        2.793   Durbin-Watson:                   2.332
# Prob(Omnibus):                  0.247   Jarque-Bera (JB):                1.861
# Skew:                           0.697   Prob(JB):                        0.394
# Kurtosis:                       3.001   Cond. No.                         168.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model3_1 = sm.ols(formula='y ~ x1 + x2 + x3', data = df)
fitted3_1 = model3_1.fit()
fitted3_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     71.64
# Date:                Sun, 01 Jul 2018   Prob (F-statistic):           1.52e-10
# Time:                        12:44:11   Log-Likelihood:                0.78235
# No. Observations:                  23   AIC:                             6.435
# Df Residuals:                      19   BIC:                             10.98
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.8895      0.451     -6.407      0.000      -3.833      -1.945
# x1             0.2367      0.036      6.549      0.000       0.161       0.312
# x2             0.2487      0.108      2.310      0.032       0.023       0.474
# x3             0.6751      0.242      2.792      0.012       0.169       1.181
# ==============================================================================
# Omnibus:                        0.491   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.782   Jarque-Bera (JB):                0.409
# Skew:                          -0.291   Prob(JB):                        0.815
# Kurtosis:                       2.702   Cond. No.                         183.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fitted3_1.params
# Out:
# Intercept   -2.889473
# x1           0.236686
# x2           0.248742
# x3           0.675132
# dtype: float64
